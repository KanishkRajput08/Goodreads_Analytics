# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_1.csv")
df2 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_2.csv")
df3 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_3.csv")
df4 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_4.csv")
df5 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_5.csv")
df6 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_6.csv")
df7 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_7.csv")
df8 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_8.csv")
df9 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_9.csv")
df10 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_10.csv")

# %%
df11 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_11.csv")
df12 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_12.csv")
df13 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_13.csv")
df14 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_14.csv")
df15 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_15.csv")
df16 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_16.csv")
df17 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_17.csv")
df18 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_18.csv")
df19 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_19.csv")
df20 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_20.csv")

# %%
df21 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_21.csv")
df22 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_22.csv")
df23 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_23.csv")
df24 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_24.csv")
df25 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_25.csv")
df26 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_26.csv")
df27 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_27.csv")
df28 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_28.csv")
df29 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_29.csv")
df30 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_30.csv")

# %%
df31 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_31.csv")
df32 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_32.csv")
df33 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_33.csv")
df34 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_34.csv")
df35 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_35.csv")
df36 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_36.csv")
df37 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_37.csv")
df38 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_38.csv")
df39 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_39.csv")
df40 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_40.csv")

# %%
df41 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_41.csv")
df42 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_42.csv")
df43 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_43.csv")
df44 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_44.csv")
df45 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_45.csv")
df46 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_46.csv")
df47 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_47.csv")
df48 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_48.csv")
df49 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_49.csv")
df50 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_50.csv")

# %%
df51 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_51.csv")
df52 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_52.csv")
df53 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_53.csv")
df54 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_54.csv")
df55 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_55.csv")
df56 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_56.csv")
df57 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_57.csv")
df58 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_58.csv")
df59 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_59.csv")
df60 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_60.csv")

# %%
df61 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_61.csv")
df62 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_62.csv")
df63 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_63.csv")
df64 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_64.csv")
df65 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_65.csv")
df66 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_66.csv")
df67 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_67.csv")
df68 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_68.csv")
df69 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_69.csv")
df70 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_70.csv")

# %%
df71 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_71.csv")
df72 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_72.csv")
df73 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_73.csv")
df74 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_74.csv")
df75 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_75.csv")
df76 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_76.csv")
df77 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_77.csv")
df78 = pd.read_csv(r"C:\Users\Kanishk Rajput\campusX\goodreads_78.csv")

# %%
book = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,
                 df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,
                 df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,
                 df31,df32,df33,df34,df35,df36,df37,df38,df39,df40,
                 df41,df42,df43,df44,df45,df46,df47,df48,df49,df50,
                 df51,df52,df53,df54,df55,df56,df57,df58,df59,df60,
                 df61,df62,df63,df64,df65,df66,df67,df68,df69,df70,
                 df71,df72,df73,df74,df75,df76,df77,df78], ignore_index = True)

# %%
book
# Out:
#                                                   title            authors  \
# 0                                    The Princess Bride    William Goldman
# 1                                  The Call of the Wild        Jack London
# 2                                             The Trial        Franz Kafka
# 3                                     She's Come Undone         Wally Lamb
# 4                               Where the Sidewalk Ends   Shel Silverstein
# ...                                                 ...                ...
# 7592                 The Very Bloody History of Britain        John Farman
# 7593  Secolul meu: confesiunile unui intelectual eur...     Aleksander Wat
# 7594                                          The Eight  Katherine Neville
# 7595  Eugenics and Other Evils : An Argument Against...    G.K. Chesterton
# 7596                             An Armenian Sketchbook    Vasily Grossman
#
#       average_rating            rating date_of_publication  \
# ...

# %%
# Export DataFrame to CSV file
book.to_csv('books.csv', index=False)
